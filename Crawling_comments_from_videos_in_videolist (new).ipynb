# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser

# https://console.cloud.google.com/apis/credentials 여기서 API발급받아 사용
DEVELOPER_KEY='AIzaSyBB6wUbqLOtqL3Ikmm9TdRxbCWgMrtUP4M' # 내 API 키값 입력

YOUTUBE_API_SERVICE_NAME='youtube'
YOUTUBE_API_VERSION='v3'

youtube = build(YOUTUBE_API_SERVICE_NAME,
              YOUTUBE_API_VERSION,
              developerKey=DEVELOPER_KEY)

# 채널아이디 첨부터 입력
playlists=youtube.playlists().list(
    channelId="UC8NDzZQhJh6WEBdljXY_wVg",
    part='snippet',
    maxResults=20).execute()

# %%
import pandas as pd

ids=[]
titles=[]
for i in playlists['items']:
    ids.append(i['id'])
    titles.append(i['snippet']['title'])
    
df=pd.DataFrame([ids,titles]).T
df.columns=['PlayLists','Titles']

df.head(10) #playlist ID 값
# Out:
#                             PlayLists        Titles
# 0  PLFQyEEEn6MSUi6PbmohmJeahaiyVQBXvX  긍정적 도덕판단(한국)
# 1  PLFQyEEEn6MSXTMxJ2Wkq2pGOdqihTE-Rd   도덕판단 사례(한국)

# %%
'''
PLFQyEEEn6MSUi6PbmohmJeahaiyVQBXvX	긍정적 도덕판단(한국)
PLFQyEEEn6MSXTMxJ2Wkq2pGOdqihTE-Rd	도덕판단 사례(한국
'''

# %%
'''
1. 비디오 리스트에서 뽑은 영상들 비디오 아이디 추출
2. 반복문과 인덱스를 이용해서 비디오 아이디를 넣어서, title, publishedAt, viewCount, likeCount, commentCount 추출가능

'''
# Out:
# '\n1. 비디오 리스트에서 뽑은 영상들 비디오 아이디 추출\n2. 반복문과 인덱스를 이용해서 비디오 아이디를 넣어서, title, publishedAt, viewCount, likeCount, commentCount 추출가능\n\n'

# %% [markdown]
# 1. 비디오 리스트에서 뽑은 영상들 비디오 아이디 추출

# %%
# 1-1: 비디오 리스트 페이지 토큰 추출

# %%
video_list_id = df["PlayLists"][1] # 또는 df["PlayLists"][0]

# %%
# 첫번째 페이지 토큰 추출
second_pgtoken = youtube.playlistItems().list(playlistId=video_list_id,
                            part='snippet').execute()["nextPageToken"]

first_pgtoken = youtube.playlistItems().list(playlistId=video_list_id,
                             pageToken = second_pgtoken,
                            part='snippet').execute()["prevPageToken"]

print(first_pgtoken)
print(second_pgtoken)
# Out:
# EAEaBlBUOkNBVQ
# EAAaBlBUOkNBVQ

# %%
page_token_list = [first_pgtoken]

try:
    for i in range(50):
        page_token = youtube.playlistItems().list(
        playlistId = video_list_id,
        part='snippet',
        pageToken= page_token_list[i],
        maxResults=100).execute()['nextPageToken']

        page_token_list.append(page_token)
    print(page_token_list)
    
    
except KeyError:
    print(page_token_list)
# Out:
# ['EAEaBlBUOkNBVQ', 'EAAaBlBUOkNBVQ', 'EAAaBlBUOkNEYw', 'EAAaBlBUOkNHaw', 'EAAaB1BUOkNKc0I', 'EAAaB1BUOkNNMEI', 'EAAaB1BUOkNQOEI', 'EAAaB1BUOkNMRUM', 'EAAaB1BUOkNPTUM', 'EAAaB1BUOkNKVUQ', 'EAAaB1BUOkNNY0Q', 'EAAaB1BUOkNQa0Q', 'EAAaB1BUOkNLc0U', 'EAAaB1BUOkNOMEU', 'EAAaB1BUOkNJOEY', 'EAAaB1BUOkNNRUY', 'EAAaB1BUOkNQTUY', 'EAAaB1BUOkNLVUc', 'EAAaB1BUOkNOY0c', 'EAAaB1BUOkNJa0g', 'EAAaB1BUOkNMc0g', 'EAAaB1BUOkNPMEg', 'EAAaB1BUOkNKOEk', 'EAAaB1BUOkNORUk', 'EAAaB1BUOkNJTUo', 'EAAaB1BUOkNMVUo', 'EAAaB1BUOkNPY0o', 'EAAaB1BUOkNKa0s', 'EAAaB1BUOkNNc0s', 'EAAaB1BUOkNQMEs', 'EAAaB1BUOkNLOEw', 'EAAaB1BUOkNPRUw', 'EAAaB1BUOkNKTU0', 'EAAaB1BUOkNNVU0', 'EAAaB1BUOkNQY00', 'EAAaB1BUOkNLa04', 'EAAaB1BUOkNOc04', 'EAAaB1BUOkNJME8', 'EAAaB1BUOkNMOE8', 'EAAaB1BUOkNQRU8', 'EAAaB1BUOkNLTVA', 'EAAaB1BUOkNOVVA', 'EAAaB1BUOkNJY1E', 'EAAaB1BUOkNMa1E']

# %%
# pageToken -> videoId

# %%
'''
도덕판단 사례(한국)
['EAEaBlBUOkNBVQ', 'EAAaBlBUOkNBVQ', 'EAAaBlBUOkNEYw', 'EAAaBlBUOkNHaw', 'EAAaB1BUOkNKc0I', 'EAAaB1BUOkNNMEI', 'EAAaB1BUOkNQOEI', 'EAAaB1BUOkNMRUM', 'EAAaB1BUOkNPTUM', 'EAAaB1BUOkNKVUQ', 'EAAaB1BUOkNNY0Q', 'EAAaB1BUOkNQa0Q', 'EAAaB1BUOkNLc0U', 'EAAaB1BUOkNOMEU', 'EAAaB1BUOkNJOEY', 'EAAaB1BUOkNNRUY', 'EAAaB1BUOkNQTUY', 'EAAaB1BUOkNLVUc', 'EAAaB1BUOkNOY0c', 'EAAaB1BUOkNJa0g', 'EAAaB1BUOkNMc0g', 'EAAaB1BUOkNPMEg', 'EAAaB1BUOkNKOEk', 'EAAaB1BUOkNORUk', 'EAAaB1BUOkNJTUo', 'EAAaB1BUOkNMVUo', 'EAAaB1BUOkNPY0o', 'EAAaB1BUOkNKa0s', 'EAAaB1BUOkNNc0s', 'EAAaB1BUOkNQMEs', 'EAAaB1BUOkNLOEw', 'EAAaB1BUOkNPRUw', 'EAAaB1BUOkNKTU0', 'EAAaB1BUOkNNVU0', 'EAAaB1BUOkNQY00', 'EAAaB1BUOkNLa04', 'EAAaB1BUOkNOc04', 'EAAaB1BUOkNJME8']
'''

'''
긍정적 도덕판단(한국)
['EAEaBlBUOkNBVQ', 'EAAaBlBUOkNBVQ']
'''
len(page_token_list)
# Out:
# 2

# %%
# 비디오 아이디 리스트 생성
playlist_videos = youtube.playlistItems().list(
    playlistId = video_list_id,
    part='snippet',
    maxResults=100)

playlistitems_list_response=playlist_videos.execute()

video_id_list = []
for i in range(len(playlistitems_list_response['items'])):
    video_id_list.append(playlistitems_list_response['items'][i]['snippet']['resourceId']['videoId'])


print(video_id_list)

'''
긍정적 도덕판단(한국)
['r0CA2vbuwN4', 'HQ65ciyVKL0', 'R6x_KKkBGy4', '6Y8Eb7JnSc4', 'hCtabu8NyFg', 'ZSGRGVKPRF8', 'M5A1evcRCD0', 'l0J5OnGYdic', '3gQcZYIn-X4', 'wJLU2r-y6XU', 'cFspNTo-Oug', 'uakDmOl7rZs', 'ZxD2t7IrPbM', 'EbsD0fWp3Lc', 'OVRJvuS1Kl4', 'izEiVz7uGcc', 'RduIbh8WOXM', 'OG-N8pDH5FE', '-o8kO3s9WLs', 'cPhbuaHJTSc', 'KKHSZspNJ_I', 'c0xYJF6LbpU', 'iyOJcxbCg30', '4zt3iz-X-vk', 'mgE-6e5AdPM', 'puGKQ-F7DWU', '4luWtk_MQNQ', 'ekG-X_ddlDY', '2cvqJryYRCM', 'suxkfG8rg6c', '3BOFFeY2P-k', 'aZhYK21z2E0', 'IYIi4v-POfo']
'''
# Out:
# ['Cz1Iw2sTOCc', '3QIEmJ1mCZY', 'FglLPXzB_pg', '7dnb4XG465Q', 'v56ra000EXI', 'yByYFQEOSAs', 'cYGeYcSDtu8', 'iMbu863ewek', 'EO41uwM4Xm4', 'nVvNVjtvVvY', '5Yk17ywg-8A', '9JDv_jI_S8c', 's9oDDvGxlbs', '2K4QgW1xLB8', 'Is3ky6oQUh4', '8AxZVM4GndE', 'p4pyKv-zwMI', 'WziBjKtD3RM', 'EtP50awfjQs', '6W2um1AGoC4', 'LSbF3ncrDxU', '1j9f4lKCtJU', 'DhMBjbpLFoM', 'u4OGk8NcamY', '_bBZaA_Xwuk', 'eI4FW6HutBE', 'YE4YwESeQF8', '-6zJdNuRk40', 'U4w9ns5cmwk', 'NuRMyVV7uyI', 'FYWY1TKKrnA', 'PszEe3LR4MI', 't5z3yAESaAk', 'LLM9aRxuwBs', 'pJ9KceL7gO0', 'lKN0Wzdqqfo', 'z65pTTiOgqc', 'I01w4CouctE', 'v8GLaLDfonE', 'HGBPe6cQQrw', 'wWhkRFK5HYo', 'xqgRz4cpeXI', 'eCsTXn2I7Zs', 'GF7qRK1gNGM', 'P6Yr15coZPw', 'ZSGRGVKPRF8', '4AHgnlaRCEI', 'jLgfunyT_Rc', 'JeTo5JijMM8', 'P4Ye5AB_ocQ']
# ...

# %%
# 비디오 아이디 -> 비디오 정보

# %%
title = []
publishedAt = []
viewCount = []
likeCount = []
commentCount = []

for i in range(len(video_id_list)):
    video_info = youtube.videos().list(part = "snippet, statistics", id = video_id_list[i]).execute()
    title.append(video_info["items"][0]["snippet"]['title'])
    publishedAt.append(video_info["items"][0]["snippet"]['publishedAt'])
    viewCount.append(video_info["items"][0]["statistics"]['viewCount'])
    #likeCount.append(video_info["items"][0]["statistics"]['likeCount'])
    commentCount.append(video_info["items"][0]["statistics"]['commentCount'])

df = pd.DataFrame()
df['title'] = title
df['publishedAt'] = publishedAt
df['viewCount'] = viewCount
#df['likeCount'] = likeCount
df['commentCount'] = commentCount
df['video_id'] = video_id_list

df
# Out:
#                                                 title           publishedAt  \
# 0   로또 1등 당첨자 농협 갔더니…"비밀번호 불러달라" (2021.05.27/뉴스데스크...  2021-05-27T11:35:50Z
# 1   [단독] "하루 18시간 노역…병들어 숨지면 바다에 버려" (2020.05.05/뉴...  2020-05-05T11:03:46Z
# 2                 "감히 우리 직원 뺨을 때려?" 발 벗고 나선 회장님 / SBS  2016-04-20T12:39:53Z
# 3       발코니서 애정행각 벌이다 '쿵'…주차된 차 위로 떨어진 여성 / JTBC 사건반장  2021-09-27T08:14:43Z
# 4   [#라이브] 겁도 없이 경찰한테 덤비면 생기는 일👊 경찰 무시하는 꼴통 시민 참교육...  2020-02-14T12:00:13Z
# 5    도대체 왜이러는 걸까? 민폐 관중이 망쳐 놓은 피, 땀, 눈물의 스포츠 현장 / 14F  2021-06-28T09:30:06Z
# 6                 차 번호판이 순식간에 '쓱'…뒤쫓은 시민 신고로 검거 / SBS  2021-12-17T12:02:48Z
# 7   [자막뉴스] 학교 다녀오면 "라면 좀.." '왜 그러지?' 했는데.. (2022.0...  2022-04-29T06:08:44Z
# 8          "네 집일 리 없잖아!" 미국 화장품 회사 CEO의 클래스!! / 비디오머그  2020-06-16T11:03:21Z
# 9   10년차 베테랑 형사의 눈썰미…휴무일 은행갔다가 범인 잡았다 / 연합뉴스 (Yonh...  2022-04-12T08:40:01Z
# 10                                     막무가내 사람 친 제네시스  2023-01-18T11:00:04Z
# ...

# %%
len(df)
# Out:
# 50

# %%
df_recent = df[:31]
df_recent
# Out:
#                                                 title           publishedAt  \
# 0            출근길 강남 도로 6km를 10분 만에 달린 경찰차! 도대체 무슨 일이?  2021-04-08T10:00:11Z
# 1            벽 타고 5층 올라가 아이 구한 '불법체류자', 끝내... / 비디오머그  2018-05-29T07:42:39Z
# 2                 "침착해" "숨 쉬어" 반지하 갇힌 이웃 구한 신림동 시민영웅들  2022-08-11T07:05:08Z
# 3         [단독] "눈을 뜨세요!"...멈췄던 심장 뛰게 한 '시민 영웅들' / YTN  2017-05-08T13:38:12Z
# 4   [자막뉴스] 폭우에 고립된 여성 구조하고 "조심히 가세요"…위험 무릅쓴 '시민 영웅...  2022-08-10T03:30:08Z
# 5                        물에 빠진 차에서 '갓난아기' 발견한 시민들의 조치  2019-06-20T07:00:02Z
# 6   비탈길서 119버스 홀로 '스르르'…시민영웅이 달려가 세웠다 / 연합뉴스 (Yonh...  2020-08-28T09:55:06Z
# 7                     "신고 좀 해주세요"…빨간 가방 여고생의 용기 / YTN  2015-04-21T07:49:43Z
# 8                     [힐링뉴스] 시민들이 구한 여고생 '또 한번의 기적을…'  2015-07-15T14:02:59Z
# 9   불 붙은 버스 속 기사 구한 시민 영웅..."누구라도 했을 일" / YTN (Yes...  2016-06-02T10:17:05Z
# 10  [영상] "3분만 늦었어도 큰일 났어요" 버스기사 구한 시민들 / YTN (Yes!...  2016-06-01T20:09:30Z
# ...

# %%
#df["commentCount"] = pd.to_numeric(df["commentCount"])
#df_s = df.sort_values(by=["commentCount"], ascending=[False])
#df_s
# Out:
#                                                 title           publishedAt  \
# 11  '아빠 수갑은 내가 챙긴다'…형사와 아들의 고속도로 추격전 / 연합뉴스 (Yonha...  2019-07-31T09:20:49Z
# 20  [현장] 위급신호 보내는 택시…'관할 타령' 경찰대신 시민이 추격 / 연합뉴스 (Y...  2018-08-09T08:07:37Z
# 17  "와~멋져요" "고기 사주고 싶다"..'현명하고 쿨한' 시민 대처에 찬사가.. [뉴...  2022-11-27T01:43:48Z
# 14  [자막뉴스] "어! 경찰차네? 내가 좀.." '쿨하게' 추격전 끝내버렸다 (2022...  2022-11-23T07:17:29Z
# 25  [자막뉴스] 승객 태우고 가던 택시기사의 제안, 흔쾌히 화재 진압 나선 '영웅들' ...  2022-03-13T05:00:31Z
# 13  [보이는 뉴스] "경찰 아저씨 여기 타세요!" 갑자기 나타난 추격전 '치트키' (M...  2022-10-15T00:30:04Z
# 32  세 번째 시도만에 가까스로 착륙‥공포의 1시간 "죽을 수도 있겠다" (2022.10...  2022-10-24T10:59:53Z
# 24  도로 위 술병들 '와장창'…학생 어벤져스 등장해 순식간에 말끔 / 연합뉴스 (Yon...  2020-09-14T10:18:52Z
# 8              [단독]지하철서 ‘억’…심정지 승객 살린 ‘퇴근길 간호사’ | 뉴스A  2021-05-15T11:04:02Z
# 5   [자막뉴스] "어어! 저차 왜 저래 약먹었나!"  그때 집게 손을 쫙 벌리더니 (2...  2023-03-11T22:43:03Z
# 31                      이태원 참사… 아비규환 현장에서 빛난 의인들｜D:이슈  2022-11-01T08:28:15Z
# ...

# %%
# 댓글 크롤링 함수
import pandas
from googleapiclient.discovery import build
    

def mass_crawler(video_id):
    api_key = "AIzaSyBB6wUbqLOtqL3Ikmm9TdRxbCWgMrtUP4M"
    #number = input("파일 넘버를 입력해주세요 \n:")
    print("크롤링을 시작합니다.",[i])
    
    comments = list()
    api_obj = build('youtube', 'v3', developerKey=api_key)
    response = api_obj.commentThreads().list(part='snippet,replies', videoId=video_id, maxResults=100).execute()
 
    while response:
        # 댓글 추출
        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']
            comments.append([comment['textDisplay'], comment['authorDisplayName'], comment['publishedAt'], comment['likeCount']])

            # 대댓글 추출
            try:
                        if item['snippet']['totalReplyCount'] == 0:
                            pass
                        else:
                             for reply_item in item['replies']['comments']:
                                    reply = reply_item['snippet']
                                    comments.append([reply['textDisplay'], reply['authorDisplayName'], reply['publishedAt'], reply['likeCount']])
            except  KeyError:
                pass



    # 다음 페이지 넘기기?
        if 'nextPageToken' in response:
            response = api_obj.commentThreads().list(part='snippet,replies', videoId=video_id, pageToken=response['nextPageToken'], maxResults=100).execute()
        else:
            break
    
    global comments_df
    comments_df = pandas.DataFrame(comments)
    return comments_df
    print("댓글이 %d개 추출되었습니다."%(len(df)))
    print("크롤링 완료")

# %%
# 여러 동영상 댓글 추출 및 합침
id_list = list(df_recent["video_id"] )

df_list = []
for i in range(len(id_list)):
    df_list.append(mass_crawler(id_list[i]))
    

intergrated_df = pd.concat(df_list)
intergrated_df
# Out:
# 크롤링을 시작합니다. [0]
# 크롤링을 시작합니다. [1]
# 크롤링을 시작합니다. [2]
# 크롤링을 시작합니다. [3]
# 크롤링을 시작합니다. [4]
# 크롤링을 시작합니다. [5]
# 크롤링을 시작합니다. [6]
# 크롤링을 시작합니다. [7]
# 크롤링을 시작합니다. [8]
# 크롤링을 시작합니다. [9]
# 크롤링을 시작합니다. [10]
# 크롤링을 시작합니다. [11]
# 크롤링을 시작합니다. [12]
# 크롤링을 시작합니다. [13]
# 크롤링을 시작합니다. [14]
# 크롤링을 시작합니다. [15]
# 크롤링을 시작합니다. [16]
# 크롤링을 시작합니다. [17]
# 크롤링을 시작합니다. [18]
# 크롤링을 시작합니다. [19]
# 크롤링을 시작합니다. [20]
# 크롤링을 시작합니다. [21]
# 크롤링을 시작합니다. [22]
# 크롤링을 시작합니다. [23]
# 크롤링을 시작합니다. [24]
# 크롤링을 시작합니다. [25]
# 크롤링을 시작합니다. [26]
# 크롤링을 시작합니다. [27]
# 크롤링을 시작합니다. [28]
# 크롤링을 시작합니다. [29]
# 크롤링을 시작합니다. [30]
#                                                      0                1  \
# 0                               검찰의 신뢰도보다 훨씬 믿음직스러운 경찰          cyx0406
# 1                     훌륭한 시민들이 아기의생명을 지켜주셨네요<br>😢감사합니다             경아 김
# 2                             이럴때 공권력을 쓰는거지 고생 하십니다 항상             반달반달
# 3    한달전쯤 부산 모 지구대에서 늦은밤 막차를 놓친 할머니가 추위를 피하기 위하여 지구...        In Ho Cho
# ...

# %%
intergrated_df.to_excel('add_comments_from_pos_videos2.xlsx', header=['comment', 'author', 'date', 'num_likes'], index=None)
