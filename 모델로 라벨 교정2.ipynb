# %%
import pandas as pd
int2 = pd.read_excel("intergrated_scores2.xlsx")

# %%
int2
# Out:
#                                                   comment  vader_polarity  \
# 0                                   와 저양반 전생에 나라구했노 타이밍보소          0.7650
# 1                       운 좋네 진짜 의대생도 아니고 레지던트나 전문의도 아닌 교수          0.2263
# 2                                    도와주신 다른분들도 정말 대단하십니다          0.6590
# 3                                         아직은 살만한 세상인거같네요          0.5267
# 4                                    살 사람은 저렇게 천운이 있어서 살어          0.4588
# ...                                                   ...             ...
# 231538                                      극한직업 취제진 힘내세요          0.5106
# 231539                                      어뢰 연습표적으로 딱이다          0.5719
# 231540  교도소 죄수들은 무상으로 최고의 식단으로 국민 세금으로 잘 먹여주는 마당에 군인들 ...          0.2500
# 231541                                너 먹고살자고 다른 사람 죽이겠다고         -0.6908
# 231542                                            적당히 처먹지          0.0000
#
#         blob_polarity   gru_nsr  gru_nsmc  binary_nsr_past  binary_nsr  \
# ...

# %%
int2.columns
# Out:
# Index(['comment', 'vader_polarity', 'blob_polarity', 'gru_nsr', 'gru_nsmc',
#        'binary_nsr_past', 'binary_nsr', 'binary_nsmc', 'category_vader',
#        'category_blob'],
#       dtype='object')

# %%
int2 = int2[['comment', 'vader_polarity', 'blob_polarity', 'gru_nsr', 'gru_nsmc']]
int2
# Out:
#                                                   comment  vader_polarity  \
# 0                                   와 저양반 전생에 나라구했노 타이밍보소          0.7650
# 1                       운 좋네 진짜 의대생도 아니고 레지던트나 전문의도 아닌 교수          0.2263
# 2                                    도와주신 다른분들도 정말 대단하십니다          0.6590
# 3                                         아직은 살만한 세상인거같네요          0.5267
# 4                                    살 사람은 저렇게 천운이 있어서 살어          0.4588
# ...                                                   ...             ...
# 231538                                      극한직업 취제진 힘내세요          0.5106
# 231539                                      어뢰 연습표적으로 딱이다          0.5719
# 231540  교도소 죄수들은 무상으로 최고의 식단으로 국민 세금으로 잘 먹여주는 마당에 군인들 ...          0.2500
# 231541                                너 먹고살자고 다른 사람 죽이겠다고         -0.6908
# 231542                                            적당히 처먹지          0.0000
#
#         blob_polarity   gru_nsr  gru_nsmc
# ...

# %%
pr4 = pd.read_excel("pr2_revised4.xlsx")
pr4
# Out:
#                                                   comment  real_label  \
# 0                                                오빠 대단합니다           1
# 1                                          이런 사람들이 국가유공자다           1
# 2       대단한 대한민국 자존심 정말 최고 단합된모습 항상 준비 되어 있는 대한민국 국민 감...           1
# 3                                           와 멋지시네요 정말 감동           1
# 4                    역시 대한민국 좋은 사람들 참 많은 나라 간혹 쓰레기가 있긴하지만           1
# ...                                                   ...         ...
# 221284                                      문을 왜 안닫고 가셧데요           0
# 221285                           아무리 봐도 저걸 왜 열고 달렸는지 이해불가           0
# 221286                                           저걸 왜 열고가           0
# 221287                                     참나 문도 안닫고 뭔짓인지           0
# 221288                            문 열려있으면 출발을 못하게는 못하는건가유           0
#
#         prediction_label  binary_nsr_past  binary_nsr  binary_nsmc  \
# ...

# %%
pd.merge(pr4, int2,
        on = "comment",
        indicator = True)
# Out:
#                                                   comment  real_label  \
# 0                                                오빠 대단합니다           1
# 1                                          이런 사람들이 국가유공자다           1
# 2       대단한 대한민국 자존심 정말 최고 단합된모습 항상 준비 되어 있는 대한민국 국민 감...           1
# 3                                           와 멋지시네요 정말 감동           1
# 4                    역시 대한민국 좋은 사람들 참 많은 나라 간혹 쓰레기가 있긴하지만           1
# ...                                                   ...         ...
# 221280                                      문을 왜 안닫고 가셧데요           0
# 221281                           아무리 봐도 저걸 왜 열고 달렸는지 이해불가           0
# 221282                                           저걸 왜 열고가           0
# 221283                                     참나 문도 안닫고 뭔짓인지           0
# 221284                            문 열려있으면 출발을 못하게는 못하는건가유           0
#
#         prediction_label  binary_nsr_past  binary_nsr  binary_nsmc  \
# ...

# %%
pr4_int = pd.merge(pr4, int2,
        on = "comment",
        indicator = True)

pr4_int
# Out:
#                                                   comment  real_label  \
# 0                                                오빠 대단합니다           1
# 1                                          이런 사람들이 국가유공자다           1
# 2       대단한 대한민국 자존심 정말 최고 단합된모습 항상 준비 되어 있는 대한민국 국민 감...           1
# 3                                           와 멋지시네요 정말 감동           1
# 4                    역시 대한민국 좋은 사람들 참 많은 나라 간혹 쓰레기가 있긴하지만           1
# ...                                                   ...         ...
# 221280                                      문을 왜 안닫고 가셧데요           0
# 221281                           아무리 봐도 저걸 왜 열고 달렸는지 이해불가           0
# 221282                                           저걸 왜 열고가           0
# 221283                                     참나 문도 안닫고 뭔짓인지           0
# 221284                            문 열려있으면 출발을 못하게는 못하는건가유           0
#
#         prediction_label  binary_nsr_past  binary_nsr  binary_nsmc  \
# ...

# %%
pr4_int["_merge"].value_counts()
# Out:
# both          221285
# left_only          0
# right_only         0
# Name: _merge, dtype: int64

# %%
pr4_int[pr4_int["_merge"] == "both"]
# Out:
#                                                   comment  real_label  \
# 0                                                오빠 대단합니다           1
# 1                                          이런 사람들이 국가유공자다           1
# 2       대단한 대한민국 자존심 정말 최고 단합된모습 항상 준비 되어 있는 대한민국 국민 감...           1
# 3                                           와 멋지시네요 정말 감동           1
# 4                    역시 대한민국 좋은 사람들 참 많은 나라 간혹 쓰레기가 있긴하지만           1
# ...                                                   ...         ...
# 221280                                      문을 왜 안닫고 가셧데요           0
# 221281                           아무리 봐도 저걸 왜 열고 달렸는지 이해불가           0
# 221282                                           저걸 왜 열고가           0
# 221283                                     참나 문도 안닫고 뭔짓인지           0
# 221284                            문 열려있으면 출발을 못하게는 못하는건가유           0
#
#         prediction_label  binary_nsr_past  binary_nsr  binary_nsmc  \
# ...

# %%
pr4_int.to_excel("pr2_revised4.xlsx")

# %%
pr4 = pd.read_excel("pr2_revised4.xlsx")
pr4
# Out:
#                                                   comment  real_label  \
# 0                                                오빠 대단합니다           1
# 1                                          이런 사람들이 국가유공자다           1
# 2       대단한 대한민국 자존심 정말 최고 단합된모습 항상 준비 되어 있는 대한민국 국민 감...           1
# 3                                           와 멋지시네요 정말 감동           1
# 4                    역시 대한민국 좋은 사람들 참 많은 나라 간혹 쓰레기가 있긴하지만           1
# ...                                                   ...         ...
# 221280                                      문을 왜 안닫고 가셧데요           0
# 221281                           아무리 봐도 저걸 왜 열고 달렸는지 이해불가           0
# 221282                                           저걸 왜 열고가           0
# 221283                                     참나 문도 안닫고 뭔짓인지           0
# 221284                            문 열려있으면 출발을 못하게는 못하는건가유           0
#
#         prediction_label  binary_nsr_past  binary_nsr  binary_nsmc  \
# ...

# %%
pr4.columns
# Out:
# Index(['comment', 'real_label', 'prediction_label', 'binary_nsr_past',
#        'binary_nsr', 'binary_nsmc', 'category_vader', 'category_blob',
#        'vader_polarity', 'blob_polarity', 'gru_nsr', 'gru_nsmc'],
#       dtype='object')

# %%
from pycaret.classification import *

# %%
exp = setup(data = pr4[['vader_polarity', 'blob_polarity', 'gru_nsr', 'gru_nsmc', 'real_label']],
            target = 'real_label')
# Out:
# <style type="text/css">
# #T_f4d6d_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f4d6d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4d6d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f4d6d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4d6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f4d6d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f4d6d_row0_col1" class="data row0 col1" >1106</td>
#     </tr>
#     <tr>
#       <th id="T_f4d6d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f4d6d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f4d6d_row1_col1" class="data row1 col1" >real_label</td>
#     </tr>
#     <tr>
#       <th id="T_f4d6d_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_f6973 th {
#   text-align: left;
# }
# ...

# %%
exp_small = setup(data = pr4[['vader_polarity', 'blob_polarity', 'gru_nsr', 'gru_nsmc', 'real_label']].sample(n=20000),
            target = 'real_label')
# Out:
# <style type="text/css">
# #T_854c5_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_854c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_854c5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_854c5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_854c5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_854c5_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_854c5_row0_col1" class="data row0 col1" >2862</td>
#     </tr>
#     <tr>
#       <th id="T_854c5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_854c5_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_854c5_row1_col1" class="data row1 col1" >real_label</td>
#     </tr>
#     <tr>
#       <th id="T_854c5_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_8da07 th {
#   text-align: left;
# }
# ...

# %%
exp_small2 = setup(data = pr4[['vader_polarity', 'blob_polarity', 'gru_nsr', 'gru_nsmc', 'real_label']].sample(n=40000),
            target = 'real_label')
# Out:
# <style type="text/css">
# #T_92f8a_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_92f8a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92f8a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_92f8a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92f8a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_92f8a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_92f8a_row0_col1" class="data row0 col1" >7452</td>
#     </tr>
#     <tr>
#       <th id="T_92f8a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_92f8a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_92f8a_row1_col1" class="data row1 col1" >real_label</td>
#     </tr>
#     <tr>
#       <th id="T_92f8a_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_8366c th {
#   text-align: left;
# }
# ...

# %%
model_rf = create_model('rf')
# Out:
# <style type="text/css">
# #T_e130c_row10_col0, #T_e130c_row10_col1, #T_e130c_row10_col2, #T_e130c_row10_col3, #T_e130c_row10_col4, #T_e130c_row10_col5, #T_e130c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_e130c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e130c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_e130c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_e130c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_e130c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_e130c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_e130c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_e130c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
predict_model(model_rf, data = pr4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7d24e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d24e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7d24e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7d24e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7d24e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7d24e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7d24e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7d24e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7d24e_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d24e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d24e_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
# ...

# %%
predict_model(model_rf, data = pr4.sample(n=100000))
# Out:
# <style type="text/css">
# </style>
# <table id="T_f9899">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9899_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f9899_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f9899_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f9899_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f9899_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f9899_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f9899_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f9899_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9899_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9899_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
# ...
