# %%
perfomance_list = [{'train_acc': 0.8125,
 'train_f1': 0.7692307692307692,
 'train_loss': 0.3867073059082031,
 'train_precision': 0.8333333333333334,
 'train_recall': 0.7142857142857143},

{'train_acc': 0.875,
 'train_f1': 0.8333333333333333,
 'train_loss': 0.3163318634033203,
 'train_precision': 0.7142857142857143,
 'train_recall': 1.0},

{'train_acc': 0.5,
 'train_f1': 0.42857142857142855,
 'train_loss': 0.7791976928710938,
 'train_precision': 0.5,
 'train_recall': 0.375},

{'train_acc': 0.8125,
 'train_f1': 0.6666666666666665,
 'train_loss': 0.46845436096191406,
 'train_precision': 0.75,
 'train_recall': 0.6},

{'train_acc': 0.8125,
 'train_f1': 0.7999999999999999,
 'train_loss': 0.6657924652099609,
 'train_precision': 0.8571428571428571,
 'train_recall': 0.75},

{'train_acc': 0.875,
 'train_f1': 0.888888888888889,
 'train_loss': 0.3176398277282715,
 'train_precision': 1.0,
 'train_recall': 0.8},

{'train_acc': 0.8125,
 'train_f1': 0.5714285714285715,
 'train_loss': 0.3045670986175537,
 'train_precision': 1.0,
 'train_recall': 0.4},

{'train_acc': 0.8125,
 'train_f1': 0.6666666666666666,
 'train_loss': 0.5185575485229492,
 'train_precision': 1.0,
 'train_recall': 0.5},

{'train_acc': 0.875,
 'train_f1': 0.875,
 'train_loss': 0.5751135349273682,
 'train_precision': 0.875,
 'train_recall': 0.875},

{'train_acc': 0.75,
 'train_f1': 0.7499999999999999,
 'train_loss': 0.5939736366271973,
 'train_precision': 1.0,
 'train_recall': 0.6},

{'train_acc': 0.8125,
 'train_f1': 0.7692307692307693,
 'train_loss': 0.3334522247314453,
 'train_precision': 1.0,
 'train_recall': 0.625},

{'train_acc': 0.6875,
 'train_f1': 0.7368421052631579,
 'train_loss': 0.39859938621520996,
 'train_precision': 0.875,
 'train_recall': 0.6363636363636364},

{'train_acc': 0.875,
 'train_f1': 0.888888888888889,
 'train_loss': 0.3449578285217285,
 'train_precision': 1.0,
 'train_recall': 0.8},

{'train_acc': 0.9375,
 'train_f1': 0.923076923076923,
 'train_loss': 0.2603335380554199,
 'train_precision': 0.8571428571428571,
 'train_recall': 1.0},

{'train_acc': 0.75,
 'train_f1': 0.75,
 'train_loss': 0.3442420959472656,
 'train_precision': 0.8571428571428571,
 'train_recall': 0.6666666666666666},

{'train_acc': 0.75,
 'train_f1': 0.7999999999999999,
 'train_loss': 0.5313754081726074,
 'train_precision': 0.7272727272727273,
 'train_recall': 0.8888888888888888},

{'train_acc': 0.8125,
 'train_f1': 0.7999999999999999,
 'train_loss': 0.4934673309326172,
 'train_precision': 0.8571428571428571,
 'train_recall': 0.75},

{'train_acc': 0.8125,
 'train_f1': 0.7692307692307692,
 'train_loss': 0.3126997947692871,
 'train_precision': 0.7142857142857143,
 'train_recall': 0.8333333333333334},

{'train_acc': 0.875,
 'train_f1': 0.6666666666666666,
 'train_loss': 0.3762855529785156,
 'train_precision': 0.6666666666666666,
 'train_recall': 0.6666666666666666},

{'train_acc': 0.8125,
 'train_f1': 0.823529411764706,
 'train_loss': 0.31757187843322754,
 'train_precision': 0.875,
 'train_recall': 0.7777777777777778},

{'train_acc': 0.8125,
 'train_f1': 0.7272727272727273,
 'train_loss': 0.3857841491699219,
 'train_precision': 1.0,
 'train_recall': 0.5714285714285714},

{'train_acc': 0.875,
 'train_f1': 0.8000000000000002,
 'train_loss': 0.23081016540527344,
 'train_precision': 0.8,
 'train_recall': 0.8},

{'train_acc': 0.875,
 'train_f1': 0.875,
 'train_loss': 0.4339470863342285,
 'train_precision': 0.875,
 'train_recall': 0.875},

{'train_acc': 0.8125,
 'train_f1': 0.823529411764706,
 'train_loss': 0.3450489044189453,
 'train_precision': 0.875,
 'train_recall': 0.7777777777777778},

{'train_acc': 0.8125,
 'train_f1': 0.8,
 'train_loss': 0.3853473663330078,
 'train_precision': 1.0,
 'train_recall': 0.6666666666666666},

{'train_acc': 0.875,
 'train_f1': 0.8000000000000002,
 'train_loss': 0.3525867462158203,
 'train_precision': 0.8,
 'train_recall': 0.8},

{'train_acc': 0.9375,
 'train_f1': 0.923076923076923,
 'train_loss': 0.25232839584350586,
 'train_precision': 1.0,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.625,
 'train_f1': 0.5714285714285715,
 'train_loss': 0.44240593910217285,
 'train_precision': 0.6666666666666666,
 'train_recall': 0.5},

{'train_acc': 1.0,
 'train_f1': 1.0,
 'train_loss': 0.10926938056945801,
 'train_precision': 1.0,
 'train_recall': 1.0},

{'train_acc': 0.9375,
 'train_f1': 0.9473684210526316,
 'train_loss': 0.17780691385269165,
 'train_precision': 1.0,
 'train_recall': 0.9},

{'train_acc': 0.8125,
 'train_f1': 0.8571428571428572,
 'train_loss': 0.2648974061012268,
 'train_precision': 0.8181818181818182,
 'train_recall': 0.9},

{'train_acc': 0.875,
 'train_f1': 0.9166666666666666,
 'train_loss': 0.203710675239563,
 'train_precision': 0.9166666666666666,
 'train_recall': 0.9166666666666666},

{'train_acc': 0.6875,
 'train_f1': 0.5454545454545454,
 'train_loss': 0.46893709897994995,
 'train_precision': 0.5,
 'train_recall': 0.6},

{'train_acc': 0.75,
 'train_f1': 0.7142857142857143,
 'train_loss': 0.41117262840270996,
 'train_precision': 0.8333333333333334,
 'train_recall': 0.625},

{'train_acc': 0.875,
 'train_f1': 0.8571428571428571,
 'train_loss': 0.31057411432266235,
 'train_precision': 1.0,
 'train_recall': 0.75},

{'train_acc': 0.75,
 'train_f1': 0.7142857142857143,
 'train_loss': 0.3326660394668579,
 'train_precision': 0.8333333333333334,
 'train_recall': 0.625},

{'train_acc': 0.8125,
 'train_f1': 0.6666666666666665,
 'train_loss': 0.3178062438964844,
 'train_precision': 0.75,
 'train_recall': 0.6},

{'train_acc': 0.875,
 'train_f1': 0.875,
 'train_loss': 0.2903822660446167,
 'train_precision': 0.875,
 'train_recall': 0.875},

{'train_acc': 0.75,
 'train_f1': 0.75,
 'train_loss': 0.4480709433555603,
 'train_precision': 0.75,
 'train_recall': 0.75},

{'train_acc': 0.8125,
 'train_f1': 0.8571428571428571,
 'train_loss': 0.3524630069732666,
 'train_precision': 1.0,
 'train_recall': 0.75},

{'train_acc': 0.8125,
 'train_f1': 0.7272727272727273,
 'train_loss': 0.3756614923477173,
 'train_precision': 1.0,
 'train_recall': 0.5714285714285714},

{'train_acc': 0.8125,
 'train_f1': 0.823529411764706,
 'train_loss': 0.3701925277709961,
 'train_precision': 0.875,
 'train_recall': 0.7777777777777778},

{'train_acc': 0.8125,
 'train_f1': 0.7692307692307692,
 'train_loss': 0.474076509475708,
 'train_precision': 0.8333333333333334,
 'train_recall': 0.7142857142857143},

{'train_acc': 0.8125,
 'train_f1': 0.7692307692307692,
 'train_loss': 0.3042328357696533,
 'train_precision': 0.8333333333333334,
 'train_recall': 0.7142857142857143},

{'train_acc': 0.8125,
 'train_f1': 0.823529411764706,
 'train_loss': 0.3792470693588257,
 'train_precision': 0.875,
 'train_recall': 0.7777777777777778},

{'train_acc': 0.8125,
 'train_f1': 0.7999999999999999,
 'train_loss': 0.22473937273025513,
 'train_precision': 0.8571428571428571,
 'train_recall': 0.75},

{'train_acc': 0.875,
 'train_f1': 0.888888888888889,
 'train_loss': 0.4209226369857788,
 'train_precision': 1.0,
 'train_recall': 0.8},

{'train_acc': 1.0,
 'train_f1': 1.0,
 'train_loss': 0.1658990979194641,
 'train_precision': 1.0,
 'train_recall': 1.0},

{'train_acc': 0.875,
 'train_f1': 0.9,
 'train_loss': 0.20590746402740479,
 'train_precision': 0.8181818181818182,
 'train_recall': 1.0},

{'train_acc': 0.8125,
 'train_f1': 0.7692307692307693,
 'train_loss': 0.32455921173095703,
 'train_precision': 1.0,
 'train_recall': 0.625},

{'train_acc': 0.9375,
 'train_f1': 0.9473684210526316,
 'train_loss': 0.1722109317779541,
 'train_precision': 1.0,
 'train_recall': 0.9},

{'train_acc': 0.8125,
 'train_f1': 0.823529411764706,
 'train_loss': 0.33142930269241333,
 'train_precision': 0.7777777777777778,
 'train_recall': 0.875},

{'train_acc': 0.75,
 'train_f1': 0.7777777777777778,
 'train_loss': 0.3902214765548706,
 'train_precision': 0.7777777777777778,
 'train_recall': 0.7777777777777778},

{'train_acc': 0.875,
 'train_f1': 0.8571428571428571,
 'train_loss': 0.19898128509521484,
 'train_precision': 0.8571428571428571,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.8125,
 'train_f1': 0.823529411764706,
 'train_loss': 0.3046417832374573,
 'train_precision': 0.875,
 'train_recall': 0.7777777777777778},

{'train_acc': 0.8125,
 'train_f1': 0.7272727272727272,
 'train_loss': 0.4041212797164917,
 'train_precision': 0.6666666666666666,
 'train_recall': 0.8},

{'train_acc': 0.875,
 'train_f1': 0.8750000000000001,
 'train_loss': 0.4188079833984375,
 'train_precision': 1.0,
 'train_recall': 0.7777777777777778},

{'train_acc': 0.9375,
 'train_f1': 0.9473684210526316,
 'train_loss': 0.14964884519577026,
 'train_precision': 1.0,
 'train_recall': 0.9},

{'train_acc': 0.9375,
 'train_f1': 0.9333333333333333,
 'train_loss': 0.25719451904296875,
 'train_precision': 0.875,
 'train_recall': 1.0},

{'train_acc': 0.875,
 'train_f1': 0.8571428571428571,
 'train_loss': 0.280120849609375,
 'train_precision': 1.0,
 'train_recall': 0.75},

{'train_acc': 0.9375,
 'train_f1': 0.9090909090909091,
 'train_loss': 0.19433653354644775,
 'train_precision': 1.0,
 'train_recall': 0.8333333333333334},

{'train_acc': 0.9375,
 'train_f1': 0.923076923076923,
 'train_loss': 0.2516716718673706,
 'train_precision': 1.0,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.75,
 'train_f1': 0.6666666666666666,
 'train_loss': 0.537013053894043,
 'train_precision': 0.6666666666666666,
 'train_recall': 0.6666666666666666},

{'train_acc': 0.8125,
 'train_f1': 0.7272727272727273,
 'train_loss': 0.4812100827693939,
 'train_precision': 1.0,
 'train_recall': 0.5714285714285714},

{'train_acc': 1.0,
 'train_f1': 1.0,
 'train_loss': 0.1451873779296875,
 'train_precision': 1.0,
 'train_recall': 1.0},

{'train_acc': 0.875,
 'train_f1': 0.8333333333333333,
 'train_loss': 0.4471120834350586,
 'train_precision': 0.7142857142857143,
 'train_recall': 1.0},

{'train_acc': 0.8125,
 'train_f1': 0.8421052631578948,
 'train_loss': 0.4023365378379822,
 'train_precision': 0.8,
 'train_recall': 0.8888888888888888},

{'train_acc': 0.875,
 'train_f1': 0.888888888888889,
 'train_loss': 0.29146528244018555,
 'train_precision': 1.0,
 'train_recall': 0.8},

{'train_acc': 0.9375,
 'train_f1': 0.9333333333333333,
 'train_loss': 0.3039647042751312,
 'train_precision': 1.0,
 'train_recall': 0.875},

{'train_acc': 0.875,
 'train_f1': 0.7499999999999999,
 'train_loss': 0.20971918106079102,
 'train_precision': 1.0,
 'train_recall': 0.6},

{'train_acc': 0.875,
 'train_f1': 0.8571428571428571,
 'train_loss': 0.3214772343635559,
 'train_precision': 0.8571428571428571,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.875,
 'train_f1': 0.9,
 'train_loss': 0.2292022705078125,
 'train_precision': 0.9,
 'train_recall': 0.9},

{'train_acc': 0.875,
 'train_f1': 0.8571428571428571,
 'train_loss': 0.1919422149658203,
 'train_precision': 0.8571428571428571,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.875,
 'train_f1': 0.8571428571428571,
 'train_loss': 0.4151758849620819,
 'train_precision': 0.8571428571428571,
 'train_recall': 0.8571428571428571},

{'train_acc': 1.0,
 'train_f1': 1.0,
 'train_loss': 0.11879661679267883,
 'train_precision': 1.0,
 'train_recall': 1.0},

{'train_acc': 0.875,
 'train_f1': 0.8571428571428571,
 'train_loss': 0.31798288226127625,
 'train_precision': 1.0,
 'train_recall': 0.75},

{'train_acc': 0.9375,
 'train_f1': 0.923076923076923,
 'train_loss': 0.21631136536598206,
 'train_precision': 0.8571428571428571,
 'train_recall': 1.0},

{'train_acc': 0.8125,
 'train_f1': 0.7272727272727273,
 'train_loss': 0.31126266717910767,
 'train_precision': 0.5714285714285714,
 'train_recall': 1.0},

{'train_acc': 0.9375,
 'train_f1': 0.9333333333333333,
 'train_loss': 0.20419222116470337,
 'train_precision': 1.0,
 'train_recall': 0.875}]

# %%
len(perfomance_list)
# Out:
# 79

# %%
import numpy as np

# %%
acc_list = []
f1_list = []
precision = []
recall_list = []

# %%
perfomance_list[0]
# Out:
# {'train_acc': 0.8125,
#  'train_f1': 0.7692307692307692,
#  'train_loss': 0.3867073059082031,
#  'train_precision': 0.8333333333333334,
#  'train_recall': 0.7142857142857143}

# %%
perfomance_list[0]["train_acc"]
# Out:
# 0.8125

# %%
for i in range(len(perfomance_list)):
    acc_list.append(perfomance_list[i]["train_acc"])
    f1_list.append(perfomance_list[i]["train_f1"])
    precision.append(perfomance_list[i]["train_precision"])
    recall_list.append(perfomance_list[i]["train_recall"])

# %%
print("epoch 1")
print("train_acc:",round(np.mean(acc_list),3))
print("train_f1:",round(np.mean(f1_list),3))
print("train_precision:",round(np.mean(precision),3))
print("train_recall:",round(np.mean(recall_list),3))


print({'val_acc': 0.85046875,
 'val_f1': 0.8516325075191467,
 'val_loss': 0.3195802867412567,
 'val_precision': 0.8516589147286822,
 'val_recall': 0.851606101947166})
# Out:
# epoch 1
# train_acc: 0.843
# train_f1: 0.816
# train_precision: 0.877
# train_recall: 0.781
# {'val_acc': 0.85046875, 'val_f1': 0.8516325075191467, 'val_loss': 0.3195802867412567, 'val_precision': 0.8516589147286822, 'val_recall': 0.851606101947166}

# %%
# version 2 (epoch=2)

# %%
# epoch 1 train
perfomance_list = [{'train_acc': 0.375,
 'train_f1': 0.37499999999999994,
 'train_loss': 0.70574951171875,
 'train_precision': 0.5,
 'train_recall': 0.3},

{'train_acc': 0.8125,
 'train_f1': 0.7692307692307692,
 'train_loss': 0.5127315521240234,
 'train_precision': 0.7142857142857143,
 'train_recall': 0.8333333333333334},

{'train_acc': 0.875,
 'train_f1': 0.888888888888889,
 'train_loss': 0.36373424530029297,
 'train_precision': 1.0,
 'train_recall': 0.8},

{'train_acc': 0.875,
 'train_f1': 0.8571428571428571,
 'train_loss': 0.31274986267089844,
 'train_precision': 0.8571428571428571,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.75,
 'train_f1': 0.8,
 'train_loss': 0.41350269317626953,
 'train_precision': 1.0,
 'train_recall': 0.6666666666666666},

{'train_acc': 0.9375,
 'train_f1': 0.9473684210526316,
 'train_loss': 0.1546916961669922,
 'train_precision': 1.0,
 'train_recall': 0.9},

{'train_acc': 0.875,
 'train_f1': 0.8000000000000002,
 'train_loss': 0.3493022918701172,
 'train_precision': 0.8,
 'train_recall': 0.8},

{'train_acc': 0.8125,
 'train_f1': 0.7999999999999999,
 'train_loss': 0.30667591094970703,
 'train_precision': 0.8571428571428571,
 'train_recall': 0.75},

{'train_acc': 0.875,
 'train_f1': 0.875,
 'train_loss': 0.3358650207519531,
 'train_precision': 0.875,
 'train_recall': 0.875},

{'train_acc': 0.9375,
 'train_f1': 0.923076923076923,
 'train_loss': 0.2341322898864746,
 'train_precision': 1.0,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.75,
 'train_f1': 0.6666666666666666,
 'train_loss': 0.47656965255737305,
 'train_precision': 1.0,
 'train_recall': 0.5},

{'train_acc': 0.875,
 'train_f1': 0.8333333333333333,
 'train_loss': 0.32138824462890625,
 'train_precision': 1.0,
 'train_recall': 0.7142857142857143},

{'train_acc': 1.0,
 'train_f1': 1.0,
 'train_loss': 0.18918275833129883,
 'train_precision': 1.0,
 'train_recall': 1.0},

{'train_acc': 0.625,
 'train_f1': 0.6666666666666665,
 'train_loss': 0.5115561485290527,
 'train_precision': 0.8571428571428571,
 'train_recall': 0.5454545454545454},

{'train_acc': 0.75,
 'train_f1': 0.7499999999999999,
 'train_loss': 0.3635561466217041,
 'train_precision': 1.0,
 'train_recall': 0.6},

{'train_acc': 0.9375,
 'train_f1': 0.9333333333333333,
 'train_loss': 0.19872188568115234,
 'train_precision': 0.875,
 'train_recall': 1.0},

{'train_acc': 0.8125,
 'train_f1': 0.7692307692307692,
 'train_loss': 0.3811854124069214,
 'train_precision': 0.7142857142857143,
 'train_recall': 0.8333333333333334},

{'train_acc': 0.9375,
 'train_f1': 0.888888888888889,
 'train_loss': 0.2639639377593994,
 'train_precision': 0.8,
 'train_recall': 1.0},

{'train_acc': 0.875,
 'train_f1': 0.8,
 'train_loss': 0.2909630537033081,
 'train_precision': 1.0,
 'train_recall': 0.6666666666666666},

{'train_acc': 0.9375,
 'train_f1': 0.9333333333333333,
 'train_loss': 0.24052214622497559,
 'train_precision': 0.875,
 'train_recall': 1.0},

{'train_acc': 0.875,
 'train_f1': 0.9230769230769231,
 'train_loss': 0.32368171215057373,
 'train_precision': 0.9230769230769231,
 'train_recall': 0.9230769230769231},

{'train_acc': 0.875,
 'train_f1': 0.8888888888888888,
 'train_loss': 0.35984480381011963,
 'train_precision': 0.8888888888888888,
 'train_recall': 0.8888888888888888},

{'train_acc': 0.875,
 'train_f1': 0.8,
 'train_loss': 0.23402166366577148,
 'train_precision': 1.0,
 'train_recall': 0.6666666666666666},

{'train_acc': 0.8125,
 'train_f1': 0.823529411764706,
 'train_loss': 0.3469892740249634,
 'train_precision': 0.875,
 'train_recall': 0.7777777777777778},

{'train_acc': 0.6875,
 'train_f1': 0.6666666666666666,
 'train_loss': 0.33630359172821045,
 'train_precision': 0.7142857142857143,
 'train_recall': 0.625},

{'train_acc': 0.9375,
 'train_f1': 0.888888888888889,
 'train_loss': 0.22402691841125488,
 'train_precision': 1.0,
 'train_recall': 0.8},

{'train_acc': 0.8125,
 'train_f1': 0.7272727272727272,
 'train_loss': 0.4208136796951294,
 'train_precision': 0.8,
 'train_recall': 0.6666666666666666},

{'train_acc': 0.875,
 'train_f1': 0.8571428571428571,
 'train_loss': 0.3877849578857422,
 'train_precision': 1.0,
 'train_recall': 0.75},

{'train_acc': 0.9375,
 'train_f1': 0.9411764705882353,
 'train_loss': 0.21994280815124512,
 'train_precision': 0.8888888888888888,
 'train_recall': 1.0},

{'train_acc': 0.75,
 'train_f1': 0.7777777777777778,
 'train_loss': 0.3788003921508789,
 'train_precision': 0.7777777777777778,
 'train_recall': 0.7777777777777778},

{'train_acc': 0.75,
 'train_f1': 0.75,
 'train_loss': 0.430952787399292,
 'train_precision': 0.8571428571428571,
 'train_recall': 0.6666666666666666},

{'train_acc': 0.75,
 'train_f1': 0.7999999999999999,
 'train_loss': 0.3881925344467163,
 'train_precision': 0.7272727272727273,
 'train_recall': 0.8888888888888888},

{'train_acc': 0.75,
 'train_f1': 0.7142857142857143,
 'train_loss': 0.42885661125183105,
 'train_precision': 0.625,
 'train_recall': 0.8333333333333334},

{'train_acc': 0.8125,
 'train_f1': 0.8,
 'train_loss': 0.28697526454925537,
 'train_precision': 1.0,
 'train_recall': 0.6666666666666666},

{'train_acc': 0.9375,
 'train_f1': 0.9090909090909091,
 'train_loss': 0.3254927396774292,
 'train_precision': 1.0,
 'train_recall': 0.8333333333333334},

{'train_acc': 0.9375,
 'train_f1': 0.9411764705882353,
 'train_loss': 0.1542009711265564,
 'train_precision': 1.0,
 'train_recall': 0.8888888888888888},

{'train_acc': 1.0,
 'train_f1': 1.0,
 'train_loss': 0.11787950992584229,
 'train_precision': 1.0,
 'train_recall': 1.0},

{'train_acc': 0.75,
 'train_f1': 0.8000000000000002,
 'train_loss': 0.36803263425827026,
 'train_precision': 0.8,
 'train_recall': 0.8},

{'train_acc': 0.625,
 'train_f1': 0.4,
 'train_loss': 0.6819343566894531,
 'train_precision': 0.5,
 'train_recall': 0.3333333333333333},

{'train_acc': 0.875,
 'train_f1': 0.8,
 'train_loss': 0.40117907524108887,
 'train_precision': 1.0,
 'train_recall': 0.6666666666666666},

{'train_acc': 0.75,
 'train_f1': 0.7142857142857143,
 'train_loss': 0.3288388252258301,
 'train_precision': 0.5555555555555556,
 'train_recall': 1.0},

{'train_acc': 0.8125,
 'train_f1': 0.8,
 'train_loss': 0.3912700414657593,
 'train_precision': 1.0,
 'train_recall': 0.6666666666666666},

{'train_acc': 0.75,
 'train_f1': 0.7499999999999999,
 'train_loss': 0.4447243809700012,
 'train_precision': 1.0,
 'train_recall': 0.6},

{'train_acc': 0.6875,
 'train_f1': 0.4444444444444445,
 'train_loss': 0.625524640083313,
 'train_precision': 0.4,
 'train_recall': 0.5},

{'train_acc': 0.875,
 'train_f1': 0.888888888888889,
 'train_loss': 0.33460691571235657,
 'train_precision': 1.0,
 'train_recall': 0.8},

{'train_acc': 0.75,
 'train_f1': 0.8333333333333333,
 'train_loss': 0.4348464012145996,
 'train_precision': 1.0,
 'train_recall': 0.7142857142857143},

{'train_acc': 0.875,
 'train_f1': 0.8571428571428571,
 'train_loss': 0.3928535580635071,
 'train_precision': 1.0,
 'train_recall': 0.75},

{'train_acc': 0.875,
 'train_f1': 0.8571428571428571,
 'train_loss': 0.25708258152008057,
 'train_precision': 1.0,
 'train_recall': 0.75},

{'train_acc': 0.9375,
 'train_f1': 0.9411764705882353,
 'train_loss': 0.15836763381958008,
 'train_precision': 1.0,
 'train_recall': 0.8888888888888888},

{'train_acc': 0.6875,
 'train_f1': 0.6666666666666666,
 'train_loss': 0.7642371654510498,
 'train_precision': 0.7142857142857143,
 'train_recall': 0.625},

{'train_acc': 0.875,
 'train_f1': 0.8333333333333334,
 'train_loss': 0.2627407908439636,
 'train_precision': 0.8333333333333334,
 'train_recall': 0.8333333333333334},

{'train_acc': 0.875,
 'train_f1': 0.8,
 'train_loss': 0.268494188785553,
 'train_precision': 1.0,
 'train_recall': 0.6666666666666666},

{'train_acc': 0.8125,
 'train_f1': 0.6666666666666666,
 'train_loss': 0.3059081435203552,
 'train_precision': 0.5,
 'train_recall': 1.0},

{'train_acc': 0.9375,
 'train_f1': 0.9411764705882353,
 'train_loss': 0.15545955300331116,
 'train_precision': 1.0,
 'train_recall': 0.8888888888888888},

{'train_acc': 0.875,
 'train_f1': 0.8571428571428571,
 'train_loss': 0.34981462359428406,
 'train_precision': 1.0,
 'train_recall': 0.75},

{'train_acc': 0.75,
 'train_f1': 0.7999999999999999,
 'train_loss': 0.4609721899032593,
 'train_precision': 0.7272727272727273,
 'train_recall': 0.8888888888888888},

{'train_acc': 0.875,
 'train_f1': 0.8750000000000001,
 'train_loss': 0.22080403566360474,
 'train_precision': 1.0,
 'train_recall': 0.7777777777777778},

{'train_acc': 0.9375,
 'train_f1': 0.9333333333333333,
 'train_loss': 0.18781960010528564,
 'train_precision': 1.0,
 'train_recall': 0.875},

{'train_acc': 0.6875,
 'train_f1': 0.7058823529411765,
 'train_loss': 0.630340576171875,
 'train_precision': 0.75,
 'train_recall': 0.6666666666666666},

{'train_acc': 0.8125,
 'train_f1': 0.7692307692307692,
 'train_loss': 0.3196421265602112,
 'train_precision': 0.7142857142857143,
 'train_recall': 0.8333333333333334},

{'train_acc': 0.6875,
 'train_f1': 0.5454545454545454,
 'train_loss': 0.710533857345581,
 'train_precision': 0.75,
 'train_recall': 0.42857142857142855},

{'train_acc': 0.9375,
 'train_f1': 0.923076923076923,
 'train_loss': 0.19071996212005615,
 'train_precision': 1.0,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.875,
 'train_f1': 0.875,
 'train_loss': 0.35583609342575073,
 'train_precision': 0.875,
 'train_recall': 0.875},

{'train_acc': 0.875,
 'train_f1': 0.8750000000000001,
 'train_loss': 0.23612439632415771,
 'train_precision': 0.7777777777777778,
 'train_recall': 1.0},

{'train_acc': 1.0,
 'train_f1': 1.0,
 'train_loss': 0.13000476360321045,
 'train_precision': 1.0,
 'train_recall': 1.0},

{'train_acc': 0.625,
 'train_f1': 0.5714285714285714,
 'train_loss': 0.44792836904525757,
 'train_precision': 0.5714285714285714,
 'train_recall': 0.5714285714285714},

{'train_acc': 0.6875,
 'train_f1': 0.7058823529411764,
 'train_loss': 0.6804129481315613,
 'train_precision': 0.6,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.8125,
 'train_f1': 0.7692307692307692,
 'train_loss': 0.358293354511261,
 'train_precision': 0.8333333333333334,
 'train_recall': 0.7142857142857143},

{'train_acc': 0.8125,
 'train_f1': 0.7999999999999999,
 'train_loss': 0.4230576157569885,
 'train_precision': 0.8571428571428571,
 'train_recall': 0.75},

{'train_acc': 0.9375,
 'train_f1': 0.923076923076923,
 'train_loss': 0.23825788497924805,
 'train_precision': 1.0,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.875,
 'train_f1': 0.875,
 'train_loss': 0.2649218440055847,
 'train_precision': 0.875,
 'train_recall': 0.875},

{'train_acc': 0.9375,
 'train_f1': 0.9333333333333333,
 'train_loss': 0.09999316930770874,
 'train_precision': 1.0,
 'train_recall': 0.875},

{'train_acc': 0.9375,
 'train_f1': 0.9333333333333333,
 'train_loss': 0.21392783522605896,
 'train_precision': 1.0,
 'train_recall': 0.875},

{'train_acc': 0.875,
 'train_f1': 0.8571428571428571,
 'train_loss': 0.22680622339248657,
 'train_precision': 0.8571428571428571,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.875,
 'train_f1': 0.8571428571428571,
 'train_loss': 0.2856997847557068,
 'train_precision': 0.8571428571428571,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.9375,
 'train_f1': 0.923076923076923,
 'train_loss': 0.2588617205619812,
 'train_precision': 1.0,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.75,
 'train_f1': 0.7777777777777778,
 'train_loss': 0.6362259387969971,
 'train_precision': 1.0,
 'train_recall': 0.6363636363636364},

{'train_acc': 0.9375,
 'train_f1': 0.9473684210526316,
 'train_loss': 0.2705855369567871,
 'train_precision': 1.0,
 'train_recall': 0.9},

{'train_acc': 0.8125,
 'train_f1': 0.7272727272727273,
 'train_loss': 0.40306639671325684,
 'train_precision': 1.0,
 'train_recall': 0.5714285714285714},

{'train_acc': 0.75,
 'train_f1': 0.7142857142857143,
 'train_loss': 0.40539273619651794,
 'train_precision': 0.8333333333333334,
 'train_recall': 0.625}]

# %%
acc_list = []
f1_list = []
precision = []
recall_list = []

# %%
for i in range(len(perfomance_list)):
    acc_list.append(perfomance_list[i]["train_acc"])
    f1_list.append(perfomance_list[i]["train_f1"])
    precision.append(perfomance_list[i]["train_precision"])
    recall_list.append(perfomance_list[i]["train_recall"])

# %%
print("epoch 1")
print("train_acc:",round(np.mean(acc_list),3))
print("train_f1:",round(np.mean(f1_list),3))
print("train_precision:",round(np.mean(precision),3))
print("train_recall:",round(np.mean(recall_list),3))


print({'val_acc': 0.85046875,
 'val_f1': 0.8516325075191467,
 'val_loss': 0.3195802867412567,
 'val_precision': 0.8516589147286822,
 'val_recall': 0.851606101947166})
# Out:
# epoch 1
# train_acc: 0.833
# train_f1: 0.812
# train_precision: 0.875
# train_recall: 0.778
# {'val_acc': 0.85046875, 'val_f1': 0.8516325075191467, 'val_loss': 0.3195802867412567, 'val_precision': 0.8516589147286822, 'val_recall': 0.851606101947166}

# %%
# epoch 2 train

# %%
perfomance_list = [{'train_acc': 0.9375,
 'train_f1': 0.9090909090909091,
 'train_loss': 0.2194978892803192,
 'train_precision': 0.8333333333333334,
 'train_recall': 1.0},

{'train_acc': 0.6875,
 'train_f1': 0.7368421052631579,
 'train_loss': 0.516905665397644,
 'train_precision': 0.6363636363636364,
 'train_recall': 0.875},

{'train_acc': 0.8125,
 'train_f1': 0.7272727272727273,
 'train_loss': 0.2511138319969177,
 'train_precision': 1.0,
 'train_recall': 0.5714285714285714},

{'train_acc': 0.9375,
 'train_f1': 0.9411764705882353,
 'train_loss': 0.18288469314575195,
 'train_precision': 1.0,
 'train_recall': 0.8888888888888888},

{'train_acc': 0.875,
 'train_f1': 0.875,
 'train_loss': 0.320644736289978,
 'train_precision': 0.875,
 'train_recall': 0.875},

{'train_acc': 0.9375,
 'train_f1': 0.9333333333333333,
 'train_loss': 0.1475069224834442,
 'train_precision': 1.0,
 'train_recall': 0.875},

{'train_acc': 0.9375,
 'train_f1': 0.923076923076923,
 'train_loss': 0.19394832849502563,
 'train_precision': 1.0,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.8125,
 'train_f1': 0.7999999999999999,
 'train_loss': 0.33979299664497375,
 'train_precision': 0.75,
 'train_recall': 0.8571428571428571},

{'train_acc': 1.0,
 'train_f1': 1.0,
 'train_loss': 0.07182836532592773,
 'train_precision': 1.0,
 'train_recall': 1.0},

{'train_acc': 0.9375,
 'train_f1': 0.888888888888889,
 'train_loss': 0.19107306003570557,
 'train_precision': 1.0,
 'train_recall': 0.8},

{'train_acc': 0.9375,
 'train_f1': 0.923076923076923,
 'train_loss': 0.21984291076660156,
 'train_precision': 1.0,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.9375,
 'train_f1': 0.9523809523809523,
 'train_loss': 0.17886775732040405,
 'train_precision': 1.0,
 'train_recall': 0.9090909090909091},

{'train_acc': 0.8125,
 'train_f1': 0.7272727272727272,
 'train_loss': 0.3161301910877228,
 'train_precision': 0.6666666666666666,
 'train_recall': 0.8},

{'train_acc': 0.875,
 'train_f1': 0.8888888888888888,
 'train_loss': 0.22748833894729614,
 'train_precision': 0.8888888888888888,
 'train_recall': 0.8888888888888888},

{'train_acc': 1.0,
 'train_f1': 1.0,
 'train_loss': 0.11183059215545654,
 'train_precision': 1.0,
 'train_recall': 1.0},

{'train_acc': 0.9375,
 'train_f1': 0.9523809523809523,
 'train_loss': 0.2761867940425873,
 'train_precision': 0.9090909090909091,
 'train_recall': 1.0},

{'train_acc': 0.8125,
 'train_f1': 0.6666666666666665,
 'train_loss': 0.22128012776374817,
 'train_precision': 0.75,
 'train_recall': 0.6},

{'train_acc': 0.6875,
 'train_f1': 0.7058823529411765,
 'train_loss': 0.5823928117752075,
 'train_precision': 0.75,
 'train_recall': 0.6666666666666666},

{'train_acc': 0.75,
 'train_f1': 0.7777777777777777,
 'train_loss': 0.3439618647098541,
 'train_precision': 0.7,
 'train_recall': 0.875},

{'train_acc': 0.9375,
 'train_f1': 0.9333333333333333,
 'train_loss': 0.19482219219207764,
 'train_precision': 0.875,
 'train_recall': 1.0},

{'train_acc': 0.9375,
 'train_f1': 0.923076923076923,
 'train_loss': 0.34193289279937744,
 'train_precision': 1.0,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.75,
 'train_f1': 0.7142857142857143,
 'train_loss': 0.45736053586006165,
 'train_precision': 1.0,
 'train_recall': 0.5555555555555556},

{'train_acc': 0.9375,
 'train_f1': 0.923076923076923,
 'train_loss': 0.18385517597198486,
 'train_precision': 1.0,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.8125,
 'train_f1': 0.8421052631578948,
 'train_loss': 0.36361241340637207,
 'train_precision': 0.8888888888888888,
 'train_recall': 0.8},

{'train_acc': 0.875,
 'train_f1': 0.8750000000000001,
 'train_loss': 0.407798171043396,
 'train_precision': 1.0,
 'train_recall': 0.7777777777777778},

{'train_acc': 0.875,
 'train_f1': 0.8571428571428571,
 'train_loss': 0.24730640649795532,
 'train_precision': 0.75,
 'train_recall': 1.0},

{'train_acc': 0.875,
 'train_f1': 0.8571428571428571,
 'train_loss': 0.24283722043037415,
 'train_precision': 0.75,
 'train_recall': 1.0},

{'train_acc': 0.9375,
 'train_f1': 0.9333333333333333,
 'train_loss': 0.1387210488319397,
 'train_precision': 0.875,
 'train_recall': 1.0},

{'train_acc': 0.875,
 'train_f1': 0.8750000000000001,
 'train_loss': 0.39570093154907227,
 'train_precision': 0.7777777777777778,
 'train_recall': 1.0},

{'train_acc': 0.9375,
 'train_f1': 0.9473684210526316,
 'train_loss': 0.11722302436828613,
 'train_precision': 0.9,
 'train_recall': 1.0},

{'train_acc': 0.75,
 'train_f1': 0.7142857142857143,
 'train_loss': 0.47523000836372375,
 'train_precision': 0.7142857142857143,
 'train_recall': 0.7142857142857143},

{'train_acc': 0.8125,
 'train_f1': 0.8421052631578948,
 'train_loss': 0.3548891246318817,
 'train_precision': 0.8888888888888888,
 'train_recall': 0.8},

{'train_acc': 0.8125,
 'train_f1': 0.7692307692307692,
 'train_loss': 0.3774140477180481,
 'train_precision': 0.8333333333333334,
 'train_recall': 0.7142857142857143},

{'train_acc': 0.75,
 'train_f1': 0.6666666666666666,
 'train_loss': 0.4521031379699707,
 'train_precision': 0.6666666666666666,
 'train_recall': 0.6666666666666666},

{'train_acc': 0.75,
 'train_f1': 0.75,
 'train_loss': 0.6444721221923828,
 'train_precision': 0.75,
 'train_recall': 0.75},

{'train_acc': 0.625,
 'train_f1': 0.6666666666666665,
 'train_loss': 0.7375108599662781,
 'train_precision': 0.5454545454545454,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.9375,
 'train_f1': 0.9090909090909091,
 'train_loss': 0.16448691487312317,
 'train_precision': 1.0,
 'train_recall': 0.8333333333333334},

{'train_acc': 0.75,
 'train_f1': 0.7777777777777777,
 'train_loss': 0.32170605659484863,
 'train_precision': 0.7,
 'train_recall': 0.875},

{'train_acc': 0.8125,
 'train_f1': 0.8,
 'train_loss': 0.33789288997650146,
 'train_precision': 0.6666666666666666,
 'train_recall': 1.0},

{'train_acc': 0.6875,
 'train_f1': 0.6666666666666666,
 'train_loss': 0.3939470946788788,
 'train_precision': 0.625,
 'train_recall': 0.7142857142857143},

{'train_acc': 0.75,
 'train_f1': 0.7777777777777777,
 'train_loss': 0.5396687984466553,
 'train_precision': 0.875,
 'train_recall': 0.7},

{'train_acc': 0.9375,
 'train_f1': 0.9333333333333333,
 'train_loss': 0.13710689544677734,
 'train_precision': 1.0,
 'train_recall': 0.875},

{'train_acc': 0.875,
 'train_f1': 0.888888888888889,
 'train_loss': 0.30950286984443665,
 'train_precision': 1.0,
 'train_recall': 0.8},

{'train_acc': 0.875,
 'train_f1': 0.8750000000000001,
 'train_loss': 0.5001161098480225,
 'train_precision': 1.0,
 'train_recall': 0.7777777777777778},

{'train_acc': 0.875,
 'train_f1': 0.9,
 'train_loss': 0.2064880132675171,
 'train_precision': 0.9,
 'train_recall': 0.9},

{'train_acc': 0.75,
 'train_f1': 0.7142857142857143,
 'train_loss': 0.3283144533634186,
 'train_precision': 0.8333333333333334,
 'train_recall': 0.625},

{'train_acc': 0.75,
 'train_f1': 0.5,
 'train_loss': 0.5910701155662537,
 'train_precision': 0.5,
 'train_recall': 0.5},

{'train_acc': 0.875,
 'train_f1': 0.8888888888888888,
 'train_loss': 0.22536754608154297,
 'train_precision': 0.8888888888888888,
 'train_recall': 0.8888888888888888},
                    
{'train_acc': 0.9375,
 'train_f1': 0.9333333333333333,
 'train_loss': 0.1859436184167862,
 'train_precision': 0.875,
 'train_recall': 1.0},

{'train_acc': 0.75,
 'train_f1': 0.7142857142857143,
 'train_loss': 0.3497490882873535,
 'train_precision': 0.625,
 'train_recall': 0.8333333333333334},

{'train_acc': 0.9375,
 'train_f1': 0.9333333333333333,
 'train_loss': 0.3047104477882385,
 'train_precision': 0.875,
 'train_recall': 1.0},

{'train_acc': 1.0,
 'train_f1': 1.0,
 'train_loss': 0.10145634412765503,
 'train_precision': 1.0,
 'train_recall': 1.0},

{'train_acc': 0.875,
 'train_f1': 0.7499999999999999,
 'train_loss': 0.3209691345691681,
 'train_precision': 0.6,
 'train_recall': 1.0},

{'train_acc': 0.9375,
 'train_f1': 0.9473684210526316,
 'train_loss': 0.20778962969779968,
 'train_precision': 1.0,
 'train_recall': 0.9},

{'train_acc': 0.8125,
 'train_f1': 0.823529411764706,
 'train_loss': 0.4792379140853882,
 'train_precision': 0.875,
 'train_recall': 0.7777777777777778},

{'train_acc': 0.8125,
 'train_f1': 0.8571428571428571,
 'train_loss': 0.33393725752830505,
 'train_precision': 1.0,
 'train_recall': 0.75},

{'train_acc': 0.875,
 'train_f1': 0.9,
 'train_loss': 0.29817986488342285,
 'train_precision': 1.0,
 'train_recall': 0.8181818181818182},

{'train_acc': 0.875,
 'train_f1': 0.875,
 'train_loss': 0.1964719444513321,
 'train_precision': 0.875,
 'train_recall': 0.875},

{'train_acc': 0.75,
 'train_f1': 0.75,
 'train_loss': 0.5308265089988708,
 'train_precision': 0.8571428571428571,
 'train_recall': 0.6666666666666666},

{'train_acc': 0.8125,
 'train_f1': 0.8571428571428572,
 'train_loss': 0.2746058702468872,
 'train_precision': 0.9,
 'train_recall': 0.8181818181818182},

{'train_acc': 1.0,
 'train_f1': 1.0,
 'train_loss': 0.05891779065132141,
 'train_precision': 1.0,
 'train_recall': 1.0},

{'train_acc': 0.8125,
 'train_f1': 0.823529411764706,
 'train_loss': 0.4464995861053467,
 'train_precision': 0.7777777777777778,
 'train_recall': 0.875},

{'train_acc': 0.875,
 'train_f1': 0.8750000000000001,
 'train_loss': 0.1979885697364807,
 'train_precision': 1.0,
 'train_recall': 0.7777777777777778},

{'train_acc': 0.875,
 'train_f1': 0.8750000000000001,
 'train_loss': 0.20046508312225342,
 'train_precision': 0.7777777777777778,
 'train_recall': 1.0},

{'train_acc': 0.8125,
 'train_f1': 0.8,
 'train_loss': 0.4795891344547272,
 'train_precision': 1.0,
 'train_recall': 0.6666666666666666},

{'train_acc': 0.875,
 'train_f1': 0.8888888888888888,
 'train_loss': 0.4345712959766388,
 'train_precision': 0.8888888888888888,
 'train_recall': 0.8888888888888888},

{'train_acc': 0.6875,
 'train_f1': 0.6666666666666666,
 'train_loss': 0.6079399585723877,
 'train_precision': 0.7142857142857143,
 'train_recall': 0.625},

{'train_acc': 0.875,
 'train_f1': 0.8333333333333334,
 'train_loss': 0.24209490418434143,
 'train_precision': 0.8333333333333334,
 'train_recall': 0.8333333333333334},

{'train_acc': 0.8125,
 'train_f1': 0.823529411764706,
 'train_loss': 0.25712892413139343,
 'train_precision': 0.875,
 'train_recall': 0.7777777777777778},

{'train_acc': 0.875,
 'train_f1': 0.75,
 'train_loss': 0.40797367691993713,
 'train_precision': 0.75,
 'train_recall': 0.75},

{'train_acc': 0.875,
 'train_f1': 0.8888888888888888,
 'train_loss': 0.18579959869384766,
 'train_precision': 0.8888888888888888,
 'train_recall': 0.8888888888888888},

{'train_acc': 0.875,
 'train_f1': 0.8333333333333334,
 'train_loss': 0.21372564136981964,
 'train_precision': 0.8333333333333334,
 'train_recall': 0.8333333333333334},

{'train_acc': 0.8125,
 'train_f1': 0.8235294117647058,
 'train_loss': 0.44056665897369385,
 'train_precision': 1.0,
 'train_recall': 0.7},

{'train_acc': 0.8125,
 'train_f1': 0.823529411764706,
 'train_loss': 0.27630358934402466,
 'train_precision': 0.875,
 'train_recall': 0.7777777777777778},

{'train_acc': 0.8125,
 'train_f1': 0.8421052631578948,
 'train_loss': 0.3970114588737488,
 'train_precision': 0.7272727272727273,
 'train_recall': 1.0},

{'train_acc': 0.8125,
 'train_f1': 0.7999999999999999,
 'train_loss': 0.2442019283771515,
 'train_precision': 0.8571428571428571,
 'train_recall': 0.75},

{'train_acc': 1.0,
 'train_f1': 1.0,
 'train_loss': 0.13378232717514038,
 'train_precision': 1.0,
 'train_recall': 1.0},

{'train_acc': 0.9375,
 'train_f1': 0.9333333333333333,
 'train_loss': 0.15587614476680756,
 'train_precision': 0.875,
 'train_recall': 1.0},

{'train_acc': 0.8125,
 'train_f1': 0.7999999999999999,
 'train_loss': 0.23675312101840973,
 'train_precision': 0.75,
 'train_recall': 0.8571428571428571}]

# %%
{'val_acc': 0.86315625,
 'val_f1': 0.8594627555441445,
 'val_loss': 0.30867302417755127,
 'val_precision': 0.8907071110224174,
 'val_recall': 0.8303361031873993}
# Out:
# {'val_acc': 0.86315625,
#  'val_f1': 0.8594627555441445,
#  'val_loss': 0.30867302417755127,
#  'val_precision': 0.8907071110224174,
#  'val_recall': 0.8303361031873993}

# %%
# last
perfomance_list = [{'train_acc': 0.59375,
 'train_f1': 0.23529411764705882,
 'train_loss': 0.6624984741210938,
 'train_precision': 0.6666666666666666,
 'train_recall': 0.14285714285714285},

{'train_acc': 0.6875,
 'train_f1': 0.6428571428571429,
 'train_loss': 0.641845703125,
 'train_precision': 0.9,
 'train_recall': 0.5},

{'train_acc': 0.84375,
 'train_f1': 0.8484848484848485,
 'train_loss': 0.3627290725708008,
 'train_precision': 0.875,
 'train_recall': 0.8235294117647058},

{'train_acc': 0.6875,
 'train_f1': 0.5833333333333334,
 'train_loss': 0.48331165313720703,
 'train_precision': 0.6363636363636364,
 'train_recall': 0.5384615384615384},

{'train_acc': 0.84375,
 'train_f1': 0.8148148148148148,
 'train_loss': 0.3440976142883301,
 'train_precision': 0.8461538461538461,
 'train_recall': 0.7857142857142857},

{'train_acc': 0.8125,
 'train_f1': 0.8500000000000001,
 'train_loss': 0.4340829849243164,
 'train_precision': 0.8095238095238095,
 'train_recall': 0.8947368421052632},

{'train_acc': 0.875,
 'train_f1': 0.8461538461538461,
 'train_loss': 0.3067803382873535,
 'train_precision': 0.8461538461538461,
 'train_recall': 0.8461538461538461},

{'train_acc': 0.78125,
 'train_f1': 0.7199999999999999,
 'train_loss': 0.40226686000823975,
 'train_precision': 0.6923076923076923,
 'train_recall': 0.75},

{'train_acc': 0.84375,
 'train_f1': 0.8387096774193549,
 'train_loss': 0.3100881576538086,
 'train_precision': 0.7647058823529411,
 'train_recall': 0.9285714285714286},

{'train_acc': 0.75,
 'train_f1': 0.7499999999999999,
 'train_loss': 0.45400500297546387,
 'train_precision': 0.9230769230769231,
 'train_recall': 0.631578947368421},

{'train_acc': 0.75,
 'train_f1': 0.6923076923076923,
 'train_loss': 0.45673537254333496,
 'train_precision': 0.9,
 'train_recall': 0.5625},

{'train_acc': 0.84375,
 'train_f1': 0.8484848484848485,
 'train_loss': 0.39054542779922485,
 'train_precision': 0.875,
 'train_recall': 0.8235294117647058},

{'train_acc': 0.84375,
 'train_f1': 0.8275862068965517,
 'train_loss': 0.33060163259506226,
 'train_precision': 0.9230769230769231,
 'train_recall': 0.75},

{'train_acc': 0.8125,
 'train_f1': 0.7692307692307693,
 'train_loss': 0.3495781421661377,
 'train_precision': 0.7692307692307693,
 'train_recall': 0.7692307692307693},

{'train_acc': 0.84375,
 'train_f1': 0.8387096774193549,
 'train_loss': 0.31539028882980347,
 'train_precision': 0.8666666666666667,
 'train_recall': 0.8125},

{'train_acc': 0.875,
 'train_f1': 0.8666666666666666,
 'train_loss': 0.3009171485900879,
 'train_precision': 0.8125,
 'train_recall': 0.9285714285714286},

{'train_acc': 0.84375,
 'train_f1': 0.8484848484848485,
 'train_loss': 0.3231380879878998,
 'train_precision': 0.875,
 'train_recall': 0.8235294117647058},

{'train_acc': 0.90625,
 'train_f1': 0.888888888888889,
 'train_loss': 0.2883402109146118,
 'train_precision': 0.9230769230769231,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.78125,
 'train_f1': 0.8205128205128205,
 'train_loss': 0.5048914551734924,
 'train_precision': 0.8888888888888888,
 'train_recall': 0.7619047619047619},

{'train_acc': 0.90625,
 'train_f1': 0.9090909090909091,
 'train_loss': 0.26104843616485596,
 'train_precision': 0.8823529411764706,
 'train_recall': 0.9375},

{'train_acc': 0.84375,
 'train_f1': 0.8387096774193549,
 'train_loss': 0.48987704515457153,
 'train_precision': 0.8666666666666667,
 'train_recall': 0.8125},

{'train_acc': 0.75,
 'train_f1': 0.7777777777777777,
 'train_loss': 0.41987407207489014,
 'train_precision': 0.875,
 'train_recall': 0.7},

{'train_acc': 0.96875,
 'train_f1': 0.9655172413793104,
 'train_loss': 0.24083805084228516,
 'train_precision': 0.9333333333333333,
 'train_recall': 1.0},

{'train_acc': 0.84375,
 'train_f1': 0.8484848484848485,
 'train_loss': 0.2712995111942291,
 'train_precision': 0.875,
 'train_recall': 0.8235294117647058},

{'train_acc': 0.8125,
 'train_f1': 0.7999999999999999,
 'train_loss': 0.4210767149925232,
 'train_precision': 0.75,
 'train_recall': 0.8571428571428571},

{'train_acc': 0.8125,
 'train_f1': 0.8,
 'train_loss': 0.47183939814567566,
 'train_precision': 1.0,
 'train_recall': 0.6666666666666666},

{'train_acc': 0.875,
 'train_f1': 0.8666666666666666,
 'train_loss': 0.29341787099838257,
 'train_precision': 0.7647058823529411,
 'train_recall': 1.0},

{'train_acc': 0.84375,
 'train_f1': 0.8484848484848485,
 'train_loss': 0.3573750853538513,
 'train_precision': 0.8235294117647058,
 'train_recall': 0.875},

{'train_acc': 0.84375,
 'train_f1': 0.8837209302325582,
 'train_loss': 0.28013139963150024,
 'train_precision': 0.9047619047619048,
 'train_recall': 0.8636363636363636},

{'train_acc': 0.875,
 'train_f1': 0.8461538461538461,
 'train_loss': 0.20943957567214966,
 'train_precision': 0.8461538461538461,
 'train_recall': 0.8461538461538461},

{'train_acc': 0.84375,
 'train_f1': 0.8148148148148148,
 'train_loss': 0.364968478679657,
 'train_precision': 0.7333333333333333,
 'train_recall': 0.9166666666666666},

{'train_acc': 0.78125,
 'train_f1': 0.7741935483870969,
 'train_loss': 0.39715495705604553,
 'train_precision': 0.75,
 'train_recall': 0.8},

{'train_acc': 0.71875,
 'train_f1': 0.6086956521739131,
 'train_loss': 0.5277048349380493,
 'train_precision': 0.7777777777777778,
 'train_recall': 0.5},

{'train_acc': 0.84375,
 'train_f1': 0.8571428571428571,
 'train_loss': 0.4627910554409027,
 'train_precision': 0.8823529411764706,
 'train_recall': 0.8333333333333334},

{'train_acc': 0.84375,
 'train_f1': 0.8148148148148148,
 'train_loss': 0.3203697204589844,
 'train_precision': 0.9166666666666666,
 'train_recall': 0.7333333333333333},

{'train_acc': 0.84375,
 'train_f1': 0.8484848484848485,
 'train_loss': 0.31399014592170715,
 'train_precision': 0.875,
 'train_recall': 0.8235294117647058},

{'train_acc': 0.78125,
 'train_f1': 0.7878787878787877,
 'train_loss': 0.34401997923851013,
 'train_precision': 0.8666666666666667,
 'train_recall': 0.7222222222222222},

{'train_acc': 0.71875,
 'train_f1': 0.608695652173913,
 'train_loss': 0.5493241548538208,
 'train_precision': 0.7,
 'train_recall': 0.5384615384615384}]

# %%
import numpy as np
acc_list = []
f1_list = []
precision = []
recall_list = []
acc_list = []
f1_list = []
precision = []
recall_list = []

for i in range(len(perfomance_list)):
    acc_list.append(perfomance_list[i]["train_acc"])
    f1_list.append(perfomance_list[i]["train_f1"])
    precision.append(perfomance_list[i]["train_precision"])
    recall_list.append(perfomance_list[i]["train_recall"])    

print("epoch 1")
print("train_acc:",round(np.mean(acc_list),3))
print("train_f1:",round(np.mean(f1_list),3))
print("train_precision:",round(np.mean(precision),3))
print("train_recall:",round(np.mean(recall_list),3))
# Out:
# epoch 1
# train_acc: 0.815
# train_f1: 0.79
# train_precision: 0.837
# train_recall: 0.768

# %%
'''
{'val_acc': 0.846725,
 'val_f1': 0.8424595934938459,
 'val_loss': 0.32860714197158813,
 'val_precision': 0.8737341434815051,
 'val_recall': 0.813346564128008}
'''
